# %%
# import libs
import urllib
import numpy as np
import re
import pandas as pd

from tqdm import tqdm

pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)

# %%
reg_1 = r"(?:<td><b>)(.+?)(?:<\/b>.+?)([\d,]+?)(?:<)"
reg_2 = r"(?:<b>)([^=]+?)(?:\:<\/b>.+?>)(.+?)(?:<\/td>)"
reg_3 = r"(?:cast_new.+?<h1>)(.+?)(?:</h1>.+?)(.+?)(?:</div>)"

# %%
save = pd.read_csv('name_and_links.csv')

# %%
def extract(link, name):
    tempurl = "https://www.the-numbers.com/movie/" + link
    page = urllib.request.Request(tempurl, headers={'User-Agent' : "Magic Browser"})
    page = urllib.request.urlopen(page)
    # read page
    html_bytes = page.read()
    html = html_bytes.decode("utf-8")

    # subset
    start_index = html.find('\"main\"')
    end_index = html.find('Further financial d')
    financial = html[start_index:end_index]
    
    start_index = html.find('Movie Details')
    end_index = html.find('cast-and-crew')
    detail = html[start_index:end_index]
    
    start_index = html.find('cast-and-crew\"')
    end_index = html.find('id=\"news\"')
    cast = html[start_index:end_index]
    
    p_financial = re.findall(reg_1, financial.replace("\n", ""), re.MULTILINE)
    p_detail = re.findall(reg_2, detail.replace("\n", ""), re.MULTILINE)
    p_cast = re.findall(reg_3, cast.replace("\n", ""), re.MULTILINE)
    p = [("link", link), ("name", name)] + p_financial + p_detail + p_cast
    
    temp = pd.DataFrame(p, columns=('key', name))
    
    return temp

# %%
df = save

# %%
for index, row in tqdm(df.iterrows(), total = df.shape[0]):
    name = row['moviename']
    link = row['link']
    
    temp = extract(link, name)
    if (index == 0):
        raw = temp
    else:
        raw = raw.set_index('key').join(temp.set_index('key'), how = "outer", lsuffix = '_left', rsuffix = '_right')
        raw['key'] = raw.axes[0].tolist()
# Out:
#   1%|          | 41/6383 [00:56<2:26:48,  1.39s/it]

# %%
raw = raw.transpose(copy = True)
# Out:
# key                                         </h1><table cellspacing=0 align="center"><tr><td width="49%" align="right"><a href="/person/115800401-Natalie-Portman">Natalie Portman</a></td><td>&nbsp;&nbsp;</td><td width="49%" align="left">Jane Foster</td></tr></table></div><P>For a description of the different acting role types we use to categorize acting perfomances, see our <a href="/glossary#acting_roles">Glossary</a>.<div class="cast_new"><h1>Production and Technical Credits  \
# Avatar: The Way of Water                                                                   NaN
# Avengers: Endgame                            table cellspacing=0 align="center"><tr><td wid...
# Pirates of the Caribbean: On Stranger Tides                                                NaN
# Avengers: Age of Ultron                                                                    NaN
# Fast X                                                                                     NaN
# key                                          </h1><table cellspacing=0 align="center"><tr><...
#
# key                                                                                     Cameos  \
# Avatar: The Way of Water                                                                   NaN
# Avengers: Endgame                            table cellspacing=0 align="center"><tr><td wid...
# Pirates of the Caribbean: On Stranger Tides                                                NaN
# Avengers: Age of Ultron                      table cellspacing=0 align="center"><tr><td wid...
# Fast X                                                                                     NaN
# key                                                                                     Cameos
#
# key                                                                                Comparisons  \
# Avatar: The Way of Water                     <td><a href="/movies/comparisons/All-Time-Top-...
# Avengers: Endgame                            <td><a href="/movies/comparisons/All-Time-Top-...
# Pirates of the Caribbean: On Stranger Tides  <td><a href="

# Pirates of the Caribbean: On Stranger Tides  <td><a href="/market/production-method/Live-Ac...
# Avengers: Age of Ultron                      <td><a href="/market/production-method/Animati...
# Fast X                                       <td><a href="/market/production-method/Live-Ac...
# key                                                                     Production&nbsp;Method
#
# key                                                             Production/Financing Companies  \
# Avatar: The Way of Water                     <td><a href="/movies/production-company/Lights...
# Avengers: Endgame                            <td><a href="/movies/production-company/Marvel...
# Pirates of the Caribbean: On Stranger Tides  <td><a href="/movies/production-company/Walt-D...
# Avengers: Age of Ultron                      <td><a href="/movies/production-company/Marvel...
# Fast X                                       <td><a href="/movies/production-company/Univer...
# key                                                             Production/Financing Companies
#
# key                                             Running Time  \
# Avatar: The Way of Water                     <td>190 minutes
# Avengers: Endgame                            <td>181 minutes
# Pirates of the Caribbean: On Stranger Tides  <td>136 minutes
# Avengers: Age of Ultron                      <td>141 minutes
# Fast X                                                   NaN
# key                                             Running Time
#
# key                                                                                     Source  \
# Avatar: The Way of Water                     <td><a href="/market/source/Original-Screenpla...
# Avengers: Endgame                            <td><a href="/market/source/Based-on-Comic-or-...
# Pirates of the Caribbean: On Stranger Tides  <td><a href="/market/source/Based-on-Theme-Par...
# Avengers: Age of Ultron                      <td><a href="/market/source/Based-on-Comic-or-...
# Fast X                                       <td><a href="/market/source/Original-Screenpla...
# key                                                                                     Source
#
# key                                                                            Supporting Cast  \
# Avatar: The Way of Water                     table cellspacing=0 align="center"><tr><td wid...
# Avengers: Endgame                            table cellspacing=0 align="center"><tr><td cla...
# Pirates of the Caribbean: On Stranger Tides  table cellspacing=0 align="center"><tr><td cla...
# Avengers: Age of Ultron                      table cellspacing=0 align="center"><tr><td wid...
# Fast X                                       table cellspacing=0 align="center"><tr><td wid...
# key                                                                            Supporting Cast
#
# key                                          Total Est. Domestic Video Sales  \
# Avatar: The Way of Water                                                 NaN
# Avengers: Endgame                                                107,842,963
# Pirates of the Caribbean: On Stranger Tides                       92,761,928
# Avengers: Age of Ultron                                           91,668,267
# Fast X                                                                   NaN
# key                                          Total Est. Domestic Video Sales
#
# key                                          Worldwide Box Office  \
# Avatar: The Way of Water                            2,310,730,803
# Avengers: Endgame                                   2,794,731,755
# Pirates of the Caribbean: On Stranger Tides         1,045,713,802
# Avengers: Age of Ultron                             1,395,316,979
# Fast X                                                        NaN
# key                                          Worldwide Box Office
#
# key                                                                                       link  \
# Avatar: The Way of Water                            Avatar-The-Way-of-Water-(2022)#tab=summary
# Avengers: Endgame                                          Avengers-Endgame-(2019)#tab=summary
# Pirates of the Caribbean: On Stranger Tides  Pirates-of-the-Caribbean-On-Stranger-Tides#tab...
# Avengers: Age of Ultron                                     Avengers-Age-of-Ultron#tab=summary
# Fast X                                                               Fast-X-(2023)#tab=summary
# key                                                                                       link
#
# key                                                                                 name
# Avatar: The Way of Water                                        Avatar: The Way of Water
# Avengers: Endgame                                                      Avengers: Endgame
# Pirates of the Caribbean: On Stranger Tides  Pirates of the Caribbean: On Stranger Tides
# Avengers: Age of Ultron                                          Avengers: Age of Ultron
# Fast X                                                                            Fast X
# key                                                                                 name
